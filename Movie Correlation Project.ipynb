# %%
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration ofthe lots we will create

# Read in the data into a dataframe using pandas

df = pd.read_csv('D:\PortFolioProjects\CorrelationInPython\movies.csv')

# %%
# Let's look at the data by taking a sample using dataframe.head

df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
# Let's see if there is any missing data by checking for percentage of nulls by column

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {:.2f}%' .format(col, pct_missing))
# Out:
# name - 0.00%
# rating - 0.01%
# genre - 0.00%
# year - 0.00%
# released - 0.00%
# score - 0.00%
# votes - 0.00%
# director - 0.00%
# writer - 0.00%
# star - 0.00%
# country - 0.00%
# budget - 0.28%
# gross - 0.02%
# company - 0.00%
# runtime - 0.00%

# %%
# Check data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change data types for our columns

df['budget'] = df['budget'].fillna(0).astype('int64')

df['gross'] = df['gross'].fillna(0).astype('int64')

# %%
# Create correct Year column by extracting it from the 'released' column

df['yearcorrect'] = df['released'].astype(str).str.extract(r'(\d{4})')

# %%
df.head(25)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
# Sort data by gross revenue

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
# Expand dataframe to display all of the data instead of top and bottom five records

pd.set_option('display.max_rows', None)

# %%
# Drop any duplicates...work in progress...
# df.drop_duplicates() ... complete script to drop any as needed
df['name'].sort_values(ascending=False).head(10)
# Out:
# 4722                      Æon Flux
# 4761       xXx: State of the Union
# 7112    xXx: Return of Xander Cage
# 4083                           xXx
# 3503                      eXistenZ
# 5642                        [Rec]²
# 166           Zorro: The Gay Blade
# 6863                      Zootopia
# 180                      Zoot Suit
# 4984                          Zoom
# Name: name, dtype: object

# %%
# Budget high correlation
# Company high correlation

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings (in Millions)')

plt.ylabel('Budget for Film (in 100 Millions)')

plt.show()

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Let's start looking at correlation
# Of note:  df.corr() will look at only numeric field in dataset
# Methods:  pearson, kendall, spearman...we will be using pearson
df.corr(method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
# High correlation between budget and gross

correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
# Let's convert dataframe strings to numbers for purposes of correlation

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized.head(25)
# Out:
#     name  rating  genre  year  released  score      votes  director  writer  \
# 0   6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1   5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2   5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3    286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4   1027       6      4  1980      1543    7.3   108000.0      1054     521
# 5   2109       6     10  1980      2502    6.4   123000.0      2528    4362
# 6   5574       6      0  1980      1771    7.9   188000.0      1412     838
# 7   4436       6      3  1980       699    8.2   330000.0      1829    1769
# 8   5281       4      0  1980      1753    6.8   101000.0      2306    1979
# 9   6213       6      3  1980      2286    7.0    10000.0      2864     423
# 10   463       4      0  1980       674    6.1    18000.0       357    3985
# ...

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
# Now let's review the numerized correlations in a simpler format

correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs.head(10)
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released   -0.011311
#       score       0.017097
#       votes       0.013088
#       director    0.009079
#       writer      0.009081
#       star        0.006472
# dtype: float64

# %%
# Now we can sort our pairs to identify high and low correlations

sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head(10)
# Out:
# budget   genre     -0.334021
# genre    budget    -0.334021
#          gross     -0.234297
# gross    genre     -0.234297
# votes    genre     -0.145307
# genre    votes     -0.145307
# score    country   -0.133348
# country  score     -0.133348
# rating   gross     -0.095450
# gross    rating    -0.095450
# dtype: float64
